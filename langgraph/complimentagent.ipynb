# %%
# !pip install typing          #install typing,langgraph,IPython
# !pip install langgraph
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26420 sha256=5699ebd2d0a62c427c119eb246329b8ebf2ea4bba1578f8b55d664627883e220
#   Stored in directory: c:\users\gangeshvar.s\appdata\local\pip\cache\wheels\9d\67\2f\53e3ef32ec48d11d7d60245255e2d71e908201d20c880c08ee
# Successfully built typing
# ...

# %%
# !pip install IPython

# %%
from typing import Dict,TypedDict
from langgraph.graph import StateGraph      #import Dict, TypedDict, StateGraph

# %%
class AgentState(TypedDict):                 #Create the state schema
    message : str

# %%
def compliment_node(state: AgentState) -> AgentState :                                     #Create the node or function
    state["message"] = state["message"]+", you're doing an amazing job learning LangGraph!"
    return state

# %%
graph = StateGraph(AgentState)                                           #Create the graph

graph.add_node("complimenter",compliment_node)
graph.set_entry_point("complimenter")
graph.set_finish_point("complimenter")

app=graph.compile()

# %%
from IPython.display import Image,display
display(Image(app.get_graph().draw_mermaid_png()))

# %%
result=app.invoke({"message":"Bob"})
                                                                  #invoke it
result["message"]
# Out:
# "Bob, you're doing an amazing job learning LangGraph!"
