# %%
from typing import TypedDict, List
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
    values: List[int]
    name: str
    result: str

# %%
def process_values(state:AgentState) -> AgentState :
    state["result"] = f"Hi there {state['name']}, your sum is {sum(state['values'])}"
    return state

# %%
graph=StateGraph(AgentState)

graph.add_node("mi",process_values)
graph.set_entry_point("mi")
graph.set_finish_point("mi")

app=graph.compile()

# %%
from IPython.display import Image,display
display(Image(app.get_graph().draw_mermaid_png()))

# %%
re=app.invoke({"values":[1,2,3,4,5],"name":"Gangesh"})
re
# Out:
# {'values': [1, 2, 3, 4, 5],
#  'name': 'Gangesh',
#  'result': 'Hi there Gangesh, your sum is 15'}

# %%
re["result"]
# Out:
# 'Hi there Gangesh, your sum is 15'
